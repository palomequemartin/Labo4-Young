# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fft import fft, fftfreq
import metodos
import plotly.express as px
import plotly.graph_objects as go
from scipy import signal

plt.style.use('./figuras.mplstyle')

# %%
df = pd.read_csv(f'./forzado sampleo alto.csv')

V = df['Tension fotodiodo [V]'].values
frecuencia = df['Frecuencia generador [Hz]']
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
t = np.linspace(0,duracion,len(V))
fig, ax = plt.subplots()

ax.plot(t,V);

# %%
fig, ax = plt.subplots()
ax.specgram(V,Fs = fs,NFFT = int(fs));
ax.set_ylim(0,600)
ax.set_ylabel('Frecuencias [Hz]')
ax.set_xlabel('Tiempo [s]')
print(frecuencia[0])
# Out:
# 266.76
