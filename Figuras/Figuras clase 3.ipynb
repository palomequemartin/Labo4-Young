# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fft import fft, fftfreq


# %matplotlib ipympl
plt.style.use('../figuras.mplstyle')

# %% [markdown]
# MEDICIÓN 0 - 20 SEGUNDOS - 2500 FS

# %%
clase = 3
duracion = 20
fs = 2500
n_medicion = 0


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
        
# figura = plt.gcf()
# plt.show()

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 1 - 20 SEGUNDOS - 2500 FS

# %%
clase = 3
duracion = 20
fs = 2500
n_medicion = 1


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
cutoff = 5000
V_trimmed = V[:cutoff]
t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
fig, ax = plt.subplots(figsize = (16,4))
ax.set_ylabel('Tensión [V]')
# ax.set_ylim((0, 10))
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
ax.plot(t,V_trimmed, '.-')

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 2 - 20 SEGUNDOS - 2500 FS

# %%
clase = 3
duracion = 20
fs = 2500
n_medicion = 2


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = 5000
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
# Out:
# Text(0.5, 1.0, 'Forzado con 15.07 Hz')

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 0 - 20 SEGUNDOS - 3500 FS

# %%
clase = 3
duracion = 20
fs = 3500
n_medicion = 0


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
# Out:
# Text(0.5, 1.0, 'Forzado con 95.26 Hz')

# %%
fig, ax = plt.subplots(figsize = (8,6))
ax.set_xlabel('Tiempo [s]')
ax.set_ylabel('Frecuencia [Hz]')

NFFT = 5000*3

ax.specgram(V, NFFT= NFFT, Fs=fs)

fontsize = 20

ax.tick_params(axis='both', which='major', labelsize=15)
ax.tick_params(axis='both', which='minor', labelsize=13)
ax.set_ylabel('Frecuencia [Hz]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
ax.set_ylim((0, 300))
# Out:
# (0.0, 300.0)

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 1 - 20 SEGUNDOS - 3500 FS

# %%
clase = 3
duracion = 20
fs = 3500
n_medicion = 1


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
# Out:
# Text(0.5, 1.0, 'Forzado con 95.26 Hz')

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 0 - 60 SEGUNDOS - 5000 FS

# %%
clase = 3
duracion = 60
fs = 5000
n_medicion = 0
f_gen = 95.26

df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
# f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
# Out:
# Text(0.5, 1.0, 'Forzado con 95.26 Hz')

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 1 - 60 SEGUNDOS - 5000 FS

# %%
clase = 3
duracion = 60
fs = 5000
n_medicion = 1


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
# Out:
# Text(0.5, 1.0, 'Forzado con 95.26 Hz')

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# MEDICIÓN 0 - 60 SEGUNDOS - 10000 FS

# %%
clase = 3
duracion = 60
fs = 10000
n_medicion = 0


df = pd.read_csv(f'../Mediciones/Clase {clase}/forzado_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')


ax.set_ylabel('Tensión [V]')
ax.set_xlabel(f'Tiempo [s]')
ax.set_title(f'Forzado con {f_gen} Hz')
# Out:
# Text(0.5, 1.0, 'Forzado con 266.76 Hz')

# %%
fig.savefig(f'Clase 3/Forzado con {f_gen} Hz - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)}.pdf')

# %% [markdown]
# DINAMICO - DURACION 60 - FS 5000

# %%
clase = 3
duracion = 60
fs = 5000
n_medicion = 0


df = pd.read_csv(f'../Mediciones/Clase {clase}/dinamico_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
# f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (16,4))
cutoff = 10000
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t[7500:8500],V_trimmed[7500:8500], '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 18

ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
ax.set_title(f'Dinamico 60s 5000fs')
# Out:
# Text(0.5, 1.0, 'Dinamico 60s 5000fs')

# %%
fig.savefig(f'Clase 3/Dinamico 3 ciclos.pdf')

# %%
frecuencias = fftfreq(N_puntos, Deltat)[:N_puntos//2]
amplitudes = np.abs(fft(V)[:N_puntos//2])
fig, ax = plt.subplots()
ax.set_xlabel(r'$f$')
ax.set_ylabel('Frecuencia [Hz]')
ax.set_title(f'FFT')
ax.set_ylabel(r'$|\hat V|$')
ax.set_yscale('log')
ax.plot(frecuencias[100:18000], amplitudes[100:18000])

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Tiempo [s]')
ax.set_ylabel('Frecuencia [Hz]')

NFFT = 25*1000

ax.specgram(V, NFFT= NFFT, Fs=fs)




# ax.set_xlim((0, 30))
ax.set_ylim((0, 300))
ax.set_title(f'NFFT ={NFFT}')
# Out:
# Text(0.5, 1.0, 'NFFT =25000')

# %%
fig.savefig(f'Clase 3/Spectrogram Dinamico - fs {int(fs)} - medición {n_medicion} - duración {int(duracion)} - NFFT = {NFFT}.pdf')

# %% [markdown]
# DINAMICO LARGO - FS 50.000 - 7 MINUTOS

# %%
duracion = 420
fs = 50000



df = pd.read_csv(rf'../dinamico largo.csv')

V = df['Tension fotodiodo [V]'].values
# f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs
# Out:
# 50000.0

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = 3000000
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 18

ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
ax.set_title(f'Dinamico 420s 50.000fs')
# Out:
# Text(0.5, 1.0, 'Dinamico 420s 50.000fs')

# %%
fig.savefig(f'../Figuras/Clase 3/Dinamico largo n ciclos.pdf')

# %%
frecuencias = fftfreq(N_puntos, Deltat)[:N_puntos//2]
amplitudes = np.abs(fft(V)[:N_puntos//2])
fig, ax = plt.subplots(figsize = (16,8))
ax.set_xlabel(r'$frecuencia\ [Hz]$')
ax.set_title(f'FFT')
ax.set_ylabel(r'$|\hat V|$')
ax.set_yscale('log')
ax.set_ylim(10**1,10**6)
ax.set_xlim(0,330)
ax.vlines(14.9,10**1,10**5,color = 'C9',linestyles= '--', linewidth = 2)
ax.vlines(94.7,10**1,10**4+5000,color = 'C9',linestyles= '--', linewidth = 2)
ax.vlines(265.8,10**1,10**3+1000,color = 'C9',linestyles= '--', linewidth = 2)

ax.plot(frecuencias[100:140000], amplitudes[100:140000],linewidth = 2,color = 'C3')

# %%
# fig.savefig(f'../Figuras/Clase 3/FFT Dinamico largo.pdf')
fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\fft dinamico largo.png')

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Tiempo [s]')
ax.set_ylabel('Frecuencia [Hz]')

NFFT = 50000*4

ax.specgram(V, NFFT= NFFT, Fs=fs)





# ax.set_xlim((0, 30))
ax.set_ylim((0, 300))
ax.set_title(f'NFFT ={NFFT}')
# Out:
# Text(0.5, 1.0, 'NFFT =200000')

# %%
fig.savefig(f'../Figuras/Clase 3/Spectrogram Dinamico largo NFFT{NFFT}.pdf')
