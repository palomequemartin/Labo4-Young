# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fft import fft, fftfreq


# %matplotlib ipympl
plt.style.use('../figuras.mplstyle')

# %% [markdown]
# DINAMICO - DURACION 60 - FS 5000

# %%
duracion = 420
fs = 50000



df = pd.read_csv(rf'../dinamico largo.csv')

V = df['Tension fotodiodo [V]'].values
# f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = 3000000
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 18

ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
ax.set_title(f'Dinamico 420s 50.000fs')
# Out:
# Text(0.5, 1.0, 'Dinamico 420s 50.000fs')

# %% [markdown]
# DINAMICO LARGO - FS 50.000 - 7 MINUTOS

# %%
duracion = 420


df = pd.read_csv(rf'../dinamico largo.csv')

V = df['Tension fotodiodo [V]'].values
# f_gen = df['Frecuencia generador [Hz]'][0]
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]

# print(fs)
N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = 3000000
if cutoff != None:
    V_trimmed = V[:cutoff]
    # t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    t = np.linspace(0,int(duracion),len(V))
    t_trimmed = t[:cutoff]
    ax.plot(t_trimmed,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 18

ax.tick_params(axis='both', which='major', labelsize=13)
ax.tick_params(axis='both', which='minor', labelsize=8)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
ax.set_title(f'Dinamico 420s 50.000fs')
# Out:
# Text(0.5, 1.0, 'Dinamico 420s 50.000fs')

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = 160000
if cutoff != None:
    V_trimmed = V[:cutoff]
    # t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    t_trimmed = t[:cutoff]
    ax.plot(t_trimmed[60000::],V_trimmed[60000::], '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 24

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=15)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
# Out:
# Text(0.5, 0, 'Tiempo [s]')

# %%
fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\dinamico zoom 1.png',dpi = 800,bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = 90000
if cutoff != None:
    V_trimmed = V[:cutoff]
    # t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    t_trimmed = t[:cutoff]
    tf = 63000
    ax.plot(t_trimmed[tf::],V_trimmed[tf::])
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 24

ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=14)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
# ax.set_title(f'Dinamico 420s 50.000fs')
ax.set_xlim(t_trimmed[tf],t_trimmed[-1])
# Out:
# (1.2598265038928924, 1.7997321511723243)

# %%
# fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\dinamico zoom 2.png',dpi = 800,bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = 70800
if cutoff != None:
    V_trimmed = V[:cutoff]
    # t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    # t = np.linspace(0,1.33,len(V_trimmed))
    t_trimmed = t[:cutoff]
    tf = 63000
    ax.plot(t_trimmed[tf::],V_trimmed[tf::])
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 24

ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=14)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
# ax.set_title(f'Dinamico 420s 50.000fs')
ax.set_xlim(t_trimmed[tf],t_trimmed[-1])
# Out:
# (1.2598265038928924, 1.4157850261763951)

# %%
# fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\dinamico zoom 3.png',dpi = 800,bbox_inches="tight")

# %%
frecuencias = fftfreq(N_puntos, Deltat)[:N_puntos//2]
amplitudes = np.abs(fft(V)[:N_puntos//2])
fig, ax = plt.subplots(figsize = (16,8))
ax.set_xlabel(r'$frecuencia\ [Hz]$')
ax.set_title(f'FFT')
ax.set_ylabel(r'$|\hat V|$')
ax.set_yscale('log')
ax.set_ylim(10**1,10**6)
ax.set_xlim(0,330)
ax.vlines(14.9,10**1,10**5,color = 'C9',linestyles= '--', linewidth = 2)
ax.vlines(94.7,10**1,10**4+5000,color = 'C9',linestyles= '--', linewidth = 2)
ax.vlines(265.8,10**1,10**3+1000,color = 'C9',linestyles= '--', linewidth = 2)

ax.plot(frecuencias[100:140000], amplitudes[100:140000],linewidth = 2,color = 'C3')

# %%
bin_frequency_width = fs / N_puntos
print(bin_frequency_width)

max_frequency_resolution_error = (bin_frequency_width * 1)/2

print(f'{max_frequency_resolution_error:.3f}')
# Out:
# 0.002380952380952381
# 0.001

# %% [markdown]
# MEDICIÓN 30s Nº1

# %%
clase = 2
duracion = 30
fs = 2500
n_medicion = 1


df = pd.read_csv(f'../Mediciones/Clase 2/dinamico_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
tiempo = df['Tiempo [s]'].values
datos_hasta_t = df['Datos hasta tiempo'].values
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs #Sampling interval [Seconds/sample]
Deltaf = fs/N_puntos #Frequency resolution [1/s]

# %%
fig, ax = plt.subplots(figsize = (10,6))
cutoff = None
if cutoff != None:
    V_trimmed = V[:cutoff]
    t = np.linspace(0,int(cutoff*Deltat),len(V_trimmed))
    ax.plot(t,V_trimmed, '.-')
else:
    t = np.linspace(0,duracion,len(V))
    ax.plot(t,V,'.-')

fontsize = 24

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=15)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)

ax.set_xlim(t[0],t[-1])
# Out:
# (0.0, 30.0)

# %%
fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\dinamico 30s.png',dpi = 800,bbox_inches="tight")

# %% [markdown]
# FIGURA PICOS DE $\alpha$

# %%
from scipy.signal import find_peaks

df = pd.read_csv(rf'..\Mediciones\Clase 3\dinamico_d60_fs5000(0).csv')

V = df['Tension fotodiodo [V]'].values
tiempo = df['Tiempo [s]'].values
datos_hasta_t = df['Datos hasta tiempo'].values
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs

# %%
fig, ax = plt.subplots(figsize = (11,6))

cutoff = 40000 #Dado que la curva no es monotona decreciente, agarro la primer parte que muestra el comportamiento exponencial

V_trimmed = V - np.mean(V) #Le resto la media para que cuando de vuelta la funcion quede positiva
V_trimmed = V_trimmed[:cutoff] 
t = np.linspace(0,duracion,len(V_trimmed))

ti = 7300

t_trimmed = t[ti::]
x = np.arange(0,cutoff)

peaks = find_peaks(-V_trimmed,height = [0,3.5],distance = 280,prominence = 1)[0]
ax.plot(t_trimmed,-V_trimmed[ti::],alpha = 0.9) #Grafico la función dada vuelta porque los datos de abajo están mejor al ppio
ax.scatter(t[peaks],-V_trimmed[peaks],color = 'C5')

# print(f'Numero de puntos = {N_puntos}',f'Longitud de Valores = {len(V)}')
# print(np.diff(x[peaks]))

fontsize = 24

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=15)
ax.set_ylabel('Tensión [V]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)

ax.set_xlim(t_trimmed[0],t_trimmed[-1])
# Out:
# (10.950273756843922, 60.0)

# %%
fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\picos alpha.png',dpi = 800,bbox_inches="tight")

# %% [markdown]
# MEDICION 30S N2

# %%
clase = 2
duracion = 30
fs = 2500
n_medicion = 2


df = pd.read_csv(f'../Mediciones/Clase 2/dinamico_d{duracion}_fs{fs}({n_medicion}).csv')

V = df['Tension fotodiodo [V]'].values
tiempo = df['Tiempo [s]'].values
datos_hasta_t = df['Datos hasta tiempo'].values
duracion = df['Duracion [s]'][0]
fs = df['Frecuencia de sampleo [Hz]'][0]


N_puntos = int(duracion*fs)
Deltat = 1/fs #Sampling interval [Seconds/sample]
Deltaf = fs/N_puntos #Frequency resolution [1/s]

# %%
frecuencias = fftfreq(N_puntos, Deltat)[:N_puntos//2]
amplitudes = np.abs(fft(V)[:N_puntos//2])

# %%
fig, ax = plt.subplots(figsize = (8,6))
ax.set_xlabel('Tiempo [s]')
ax.set_ylabel('Frecuencia [Hz]')

NFFT = 5000*3

ax.specgram(V, NFFT= NFFT, Fs=fs)

fontsize = 20

ax.tick_params(axis='both', which='major', labelsize=15)
ax.tick_params(axis='both', which='minor', labelsize=13)
ax.set_ylabel('Frecuencia [Hz]',fontsize = fontsize)
ax.set_xlabel(f'Tiempo [s]',fontsize = fontsize)
ax.set_ylim((0, 300))
# Out:
# (0.0, 300.0)

# %%
fig.savefig(rf'C:\Users\lucio\OneDrive\Documentos\UBA\Materias\Labo IV\Young\spectrogram.png',dpi = 800,bbox_inches="tight")
